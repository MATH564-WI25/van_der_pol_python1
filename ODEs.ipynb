# %% [markdown]
# ## 1. solving the ODE $y' = 2t$

# %%
import numpy as np
import scipy
from scipy.integrate import odeint

tspan = np.linspace(0, 5)
y0 = 0

def model(y, t):
    dydt = 2 * t
    return [dydt]

y = odeint(model, y0, tspan)

# %%
from matplotlib import pyplot as plt
plt.plot(tspan, y)
plt.xlabel('t')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## 2. van der pol oscillator
#
# $$ y_1' = y_2$$
# $$y_2' = \mu(1 - y_1^2)y_2 - y_1$$

# %%
def vdp1(y, t, mu):
    y1, y2 = y
    dy1dt = y2
    dy2dt = mu * (1 - y1**2) * y2 - y1
    return [dy1dt, dy2dt]

mu = 1
t = np.linspace(0, 20, 1000)
Y = odeint(vdp1, [2, 0], t, args=(mu,))

# %%
plt.plot(t, Y[:, 0], '-o', label='y1')
plt.plot(t, Y[:, 1], '-o', label='y2')
plt.xlabel('t')
plt.legend()

# %% [markdown]
# ## 3. finding equilibriua

# %%
from scipy.optimize import fsolve

fsolve(vdp1, [2, 0], args=(0, 1,), full_output=True)
# Out:
# (array([0., 0.]),
#  {'nfev': 5, 'fjac': array([[ 0.,  1.],
#          [-1.,  0.]]), 'r': array([-1., -3., -1.]), 'qtf': array([4.36228831e-12, 0.00000000e+00]), 'fvec': array([0., 0.])},
#  1,
#  'The solution converged.')
